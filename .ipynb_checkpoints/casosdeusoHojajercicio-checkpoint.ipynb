# %% [markdown]
# cdcd

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data_students=pd.read_csv("C:\\Users\\ilopezg\\Downloads\\clean_students_complete.csv")
data_students.head()
# Out:
#    Unnamed: 0  Student ID     student_name gender grade        school_name  \
# 0           0           0     Paul Bradley      M   9th  Huang High School
# 1           1           1     Victor Smith      M  12th  Huang High School
# 2           2           2  Kevin Rodriguez      M  12th  Huang High School
# 3           3           3    Richard Scott      M  12th  Huang High School
# 4           4           4       Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
#CAMBIO DE INDICE
#(keys, drop=true, append=False, inplace=False, verify_integrity=False)
data_students.set_index("Student ID", inplace=True)
data_students
# Out:
#             Unnamed: 0     student_name gender grade         school_name  \
# Student ID
# 0                    0     Paul Bradley      M   9th   Huang High School
# 1                    1     Victor Smith      M  12th   Huang High School
# 2                    2  Kevin Rodriguez      M  12th   Huang High School
# 3                    3    Richard Scott      M  12th   Huang High School
# 4                    4       Bonnie Ray      F   9th   Huang High School
# ...                ...              ...    ...   ...                 ...
# 39165            39165     Donna Howard      F  12th  Thomas High School
# 39166            39166        Dawn Bell      F  10th  Thomas High School
# 39167            39167   Rebecca Tanner      F   9th  Thomas High School
# 39168            39168     Desiree Kidd      F  10th  Thomas High School
# 39169            39169  Carolyn Jackson      F  11th  Thomas High School
#
#             reading_score  math_score
# Student ID
# ...

# %%
data_students=data_students.drop(["Unnamed: 0"], axis=1)
data_students
# Out:
#                student_name gender grade         school_name  reading_score  \
# Student ID
# 0              Paul Bradley      M   9th   Huang High School             66
# 1              Victor Smith      M  12th   Huang High School             94
# 2           Kevin Rodriguez      M  12th   Huang High School             90
# 3             Richard Scott      M  12th   Huang High School             67
# 4                Bonnie Ray      F   9th   Huang High School             97
# ...                     ...    ...   ...                 ...            ...
# 39165          Donna Howard      F  12th  Thomas High School             99
# 39166             Dawn Bell      F  10th  Thomas High School             95
# 39167        Rebecca Tanner      F   9th  Thomas High School             73
# 39168          Desiree Kidd      F  10th  Thomas High School             99
# 39169       Carolyn Jackson      F  11th  Thomas High School             95
#
#             math_score
# Student ID
# ...

# %%
data_students[data_students["student_name"]=="Michael Smith"].count()
# Out:
# student_name     26
# gender           26
# grade            26
# school_name      26
# reading_score    26
# math_score       26
# dtype: int64

# %%
data_students["gender"].value_counts()
# Out:
# F    19735
# M    19435
# Name: gender, dtype: int64

# %%
name=data_students["gender"].value_counts().keys()
name
# Out:
# Index(['F', 'M'], dtype='object')

# %%
plot=data_students["gender"].value_counts().plot.pie(labels=name, autopct="%0.1f%%",figsize=(10,5))

# %% [markdown]
# Presenta la forma que creas más conveniente para describir cuántos alumnos hay por grados

# %%
data_students["grade"].value_counts()
# Out:
# 9th     11408
# 10th    10168
# 11th     9695
# 12th     7899
# Name: grade, dtype: int64

# %%
grades=data_students["grade"].value_counts().keys()
grades
# Out:
# Index(['9th', '10th', '11th', '12th'], dtype='object')

# %%
pie=data_students["grade"].value_counts().plot(kind="bar",color='#5F9EA0',figsize=(10,5))
plt.title("Alumnos por grado")
plt.xlabel("Grado")
plt.ylabel("Alumnos")
# Out:
# Text(0, 0.5, 'Alumnos')

# %%
data_students.groupby(["gender","school_name","reading_score"])
#data_students.groupby(["school_name"]).mean()
data_students.head()
# Out:
#                student_name gender grade        school_name  reading_score  \
# Student ID
# 0              Paul Bradley      M   9th  Huang High School             66
# 1              Victor Smith      M  12th  Huang High School             94
# 2           Kevin Rodriguez      M  12th  Huang High School             90
# 3             Richard Scott      M  12th  Huang High School             67
# 4                Bonnie Ray      F   9th  Huang High School             97
#
#             math_score
# Student ID
# 0                   79
# 1                   61
# 2                   60
# 3                   58
# 4                   84

# %%
datasort=data_students.sort_values("reading_score", ascending=False) #Se ordenan de mayor a menor los paises más ganadores
datasort.head()
# Out:
#                 student_name gender grade            school_name  \
# Student ID
# 8885        Matthew Williams      M  11th  Hernandez High School
# 23073        Jennifer Miller      F  11th     Holden High School
# 23074         Brian Williams      M  12th     Holden High School
# 36854        William Brennan      M   9th       Ford High School
# 16070         Ashley Fleming      F  11th    Cabrera High School
#
#             reading_score  math_score
# Student ID
# 8885                   99          62
# 23073                  99          93
# 23074                  99          85
# 36854                  99          97
# 16070                  99          78

# %%
nu=datasort.groupby("school_name")["reading_score"].nunique()
nu
# Out:
# school_name
# Bailey High School       37
# Cabrera High School      31
# Figueroa High School     37
# Ford High School         37
# Griffin High School      31
# Hernandez High School    37
# Holden High School       31
# Huang High School        37
# Johnson High School      37
# Pena High School         31
# Rodriguez High School    37
# Shelton High School      31
# Thomas High School       31
# Wilson High School       31
# Wright High School       31
# Name: reading_score, dtype: int64

# %%
prommax=data_students.groupby(["school_name"]).max()
prommax
#Ver como eliminar una columna para eliminar la de math
# Out:
#                            student_name gender grade  reading_score  \
# school_name
# Bailey High School     Zachary Williams      M   9th             99
# Cabrera High School          Zoe Gaines      M   9th             99
# Figueroa High School      Zachary Wyatt      M   9th             99
# Ford High School             Zoe Burton      M   9th             99
# Griffin High School         Zoe Burgess      M   9th             99
# Hernandez High School         Zoe Meyer      M   9th             99
# Holden High School          Zoe Hawkins      M   9th             99
# Huang High School          Zoe Mcmillan      M   9th             99
# Johnson High School     Zachary Whitney      M   9th             99
# Pena High School         Zachary Pruitt      M   9th             99
# Rodriguez High School   Zachary Winters      M   9th             99
# Shelton High School           Zoe Mayer      M   9th             99
# Thomas High School            Zoe Allen      M   9th             99
# ...

# %%
nu=prommax.groupby("school_name")["reading_score"].nunique()
nu
# Out:
# school_name
# Bailey High School       1
# Cabrera High School      1
# Figueroa High School     1
# Ford High School         1
# Griffin High School      1
# Hernandez High School    1
# Holden High School       1
# Huang High School        1
# Johnson High School      1
# Pena High School         1
# Rodriguez High School    1
# Shelton High School      1
# Thomas High School       1
# Wilson High School       1
# Wright High School       1
# Name: reading_score, dtype: int64

# %%
justreading=prommax.drop(columns=["math_score"])
justreading
# Out:
#                            student_name gender grade  reading_score
# school_name
# Bailey High School     Zachary Williams      M   9th             99
# Cabrera High School          Zoe Gaines      M   9th             99
# Figueroa High School      Zachary Wyatt      M   9th             99
# Ford High School             Zoe Burton      M   9th             99
# Griffin High School         Zoe Burgess      M   9th             99
# Hernandez High School         Zoe Meyer      M   9th             99
# Holden High School          Zoe Hawkins      M   9th             99
# Huang High School          Zoe Mcmillan      M   9th             99
# Johnson High School     Zachary Whitney      M   9th             99
# Pena High School         Zachary Pruitt      M   9th             99
# Rodriguez High School   Zachary Winters      M   9th             99
# Shelton High School           Zoe Mayer      M   9th             99
# Thomas High School            Zoe Allen      M   9th             99
# ...

# %%
al=prommax.groupby("school_name")["reading_score"].nunique()
al.head()
# Out:
# school_name
# Bailey High School      1
# Cabrera High School     1
# Figueroa High School    1
# Ford High School        1
# Griffin High School     1
# Name: reading_score, dtype: int64
